# %%
from get_offres import GetOffres

# %%
getOffres = GetOffres("https://www.sfds.asso.fr/fr/n/506-consulter_les_offres_demploi/?jedu=MASTER&jcon=&jp=3")

df = getOffres.fetch_offres()
# Out:
# Les données ont été sauvegardées sous ../data/jobs.csv à 2025-10-19 01:03:05.637379

# %%
df
# Out:
#                                           TITRE_OFFRE  \
# 0   Stage en apprentissage statistique pour la pré...
# 1               M2 internship in Genetic Epidemiology
# 2   Offre de thèse "Clinical information extractio...
# 3   Stage M2 Maternal tobacco smoking and psychoso...
# 4   Stage M2 : Impact des biothérapies sur les tra...
# 5   Machine Learning pour l’exploration de la sous...
# 6   Development of filtering algorithms based on h...
# 7    PhD Position - Targer trial emulation - Grenoble
# 8   PhD Position:  Deep Generative Models of Physi...
# 9   Ingénieur(e) Data Analyste en pharmacoépidémio...
# 10  Researcher in clinical evaluation and regulati...
# 11  Permanent research engineer position as Head o...
# 12  Clustering de données fonctionnelles avec appl...
#
#                    DATE_PUB_OFFRE  \
# 0   Publiée le 18/09/2025 22:01.
# 1   Publiée le 12/09/2025 09:15.
# 2   Publiée le 11/09/2025 16:29.
# 3   Publiée le 10/09/2025 08:46.
# ...
